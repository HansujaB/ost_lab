# %% [markdown]
# <a href="https://colab.research.google.com/github/HansujaB/ost_lab/blob/main/OST_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Experiment 10

# %%
import pandas as pd
df = pd.read_csv('data.csv')
print(df.describe()) # Shows average, min, and max
# Out:
#              Sales
# count    12.000000
# mean   1983.333333
# std     483.985975
# min    1200.000000
# 25%    1675.000000
# 50%    1950.000000
# 75%    2225.000000
# max    3000.000000

# %%
import matplotlib.pyplot as plt
plt.plot(df['Month'], df['Sales'], marker='o', color='red')
plt.xticks(rotation=45)
plt.title('Monthly Sales Trend')
plt.show()
